# %%
import os
from os import path

import pandas as pd
print(pd.__version__)

import numpy as np
print(np.__version__)

import sys
print(sys.version)

df = pd.DataFrame(np.random.rand(150, 50))
df2 = pd.DataFrame(np.random.rand(200, 153))
df.columns.values = list()
# Out:
# 1.0.1
# 1.18.1
# 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]
#            0         1         2         3         4         5         6   \
# 0    0.918996  0.227225  0.638660  0.606691  0.595909  0.328400  0.165122
# 1    0.879444  0.436883  0.900596  0.306595  0.765620  0.415965  0.083481
# 2    0.608756  0.644856  0.717633  0.431055  0.118120  0.543032  0.217546
# 3    0.061412  0.201572  0.590909  0.827550  0.577432  0.175696  0.875756
# 4    0.544351  0.774345  0.019464  0.911590  0.732612  0.099697  0.871165
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.456813  0.716176  0.309581  0.480659  0.581311  0.242500  0.521620
# 146  0.987400  0.118794  0.769255  0.259405  0.788614  0.440842  0.980316
# 147  0.206663  0.313582  0.870562  0.964191  0.606379  0.095705  0.915941
# 148  0.574790  0.439663  0.205434  0.051080  0.173372  0.523285  0.543487
# ...

# %%
# we don't have server dies issue in this test code...

# need to add a string column to make the next line work, or it gives error.
df['0'] = df2.iloc[:,3:].columns
df.columns.values[[2,4,6]] = ['age$^2$', 'age*gender', 'age$^2$*gender']
df
# Out:
#             0         1   age$^2$         3  age*gender         5  \
# 0    0.918996  0.227225  0.638660  0.606691    0.595909  0.328400
# 1    0.879444  0.436883  0.900596  0.306595    0.765620  0.415965
# 2    0.608756  0.644856  0.717633  0.431055    0.118120  0.543032
# 3    0.061412  0.201572  0.590909  0.827550    0.577432  0.175696
# 4    0.544351  0.774345  0.019464  0.911590    0.732612  0.099697
# ..        ...       ...       ...       ...         ...       ...
# 145  0.456813  0.716176  0.309581  0.480659    0.581311  0.242500
# 146  0.987400  0.118794  0.769255  0.259405    0.788614  0.440842
# 147  0.206663  0.313582  0.870562  0.964191    0.606379  0.095705
# 148  0.574790  0.439663  0.205434  0.051080    0.173372  0.523285
# 149  0.416823  0.329200  0.814857  0.355505    0.648602  0.461600
#
#      age$^2$*gender         7         8         9  ...        41        42  \
# 0          0.165122  0.581518  0.249105  0.105960  ...  0.887582  0.398421
# ...
